# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imporando-Pacotes" data-toc-modified-id="Imporando-Pacotes-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imporando Pacotes</a></span></li><li><span><a href="#Função-de-Entrada" data-toc-modified-id="Função-de-Entrada-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Função de Entrada</a></span></li><li><span><a href="#Dicionários" data-toc-modified-id="Dicionários-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Dicionários</a></span></li><li><span><a href="#Cenários" data-toc-modified-id="Cenários-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Cenários</a></span></li><li><span><a href="#viz" data-toc-modified-id="viz-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>viz</a></span></li><li><span><a href="#Cruzando-com-indicadores" data-toc-modified-id="Cruzando-com-indicadores-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Cruzando com indicadores</a></span></li><li><span><a href="#Otimização" data-toc-modified-id="Otimização-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Otimização</a></span></li></ul></div>

# %% [markdown]
# # Imporando Pacotes

# %%
# Importando as bibliotecas
import numpy as np # pacote para funções matemáticas
import pandas as pd # pacote para a manipulação dos dados em tabela
from IPython.display import display # Allows the use of display() for DataFrames
import matplotlib.pyplot as plt # pacote para fazer gráficos
import matplotlib.patches as mpatches
import seaborn as sns
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go


import pandas_ta as ta
import talib
import mplfinance as mpf

import optuna
from optuna.visualization import plot_contour
from optuna.visualization import plot_edf
from optuna.visualization import plot_intermediate_values
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_parallel_coordinate
from optuna.visualization import plot_param_importances
from optuna.visualization import plot_slice

pd.set_option("display.max_columns", 40)
pd.set_option('display.max_rows', 500)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
from futures_backtester import Backtester

# %% [markdown]
# # Função de Entrada

# %%
def entrada(df, period, thres, allowed_hours=None, position_type="both"):

    df = df.copy()  # Para evitar SettingWithCopyWarning
    
    df['rsi'] = df.ta.rsi(length=4)
    df[f'atr_{period}'] = df.ta.atr(length=period)
    df[f'atr_pct_{period}'] = df[f'atr_{period}'] / df['close'] * 100
    
    # VWAP
    df['vwap'] = df.ta.vwap(high='high', low='low', close='close', volume='volume')
    
    # Condições de entrada
    price = df['close']
    cond_long = (price > df['vwap']) & (price.shift(1) <= df['vwap'].shift(1)) & (df[f'atr_pct_{period}']  > thres) #& (df['rsi']  < 50) 
    cond_short = (price < df['vwap']) & (price.shift(1) >= df['vwap'].shift(1)) & (df[f'atr_pct_{period}']  > thres) #& (df['rsi']  < 50) 

    df['position'] = 0
    if position_type == "short":
        df.loc[cond_short, "position"] = +1
    elif position_type == "long":
        df.loc[cond_long, "position"] = -1
    else:
        df.loc[cond_long, "position"] = +1
        df.loc[cond_short, "position"] = -1

    # Restrição de horário
    if allowed_hours is not None:
        df.loc[~df.index.to_series().dt.hour.isin(allowed_hours), 'position'] = 0
        
    df.loc[(df.index.to_series().dt.hour==9) & (df.index.to_series().dt.minute<=10), 'position'] = 0

    return df['position']

# %% [markdown]
# # Dicionários

# %%
from config.dicts_params import dict_custos, dict_valor_lot, dict_path

# %% [markdown]
# # Cenários

# %%
# win 5 min
{'sl': 300, 'tp': 620, 'LENGTH_RSI': 13, 'RSI_LOW': 30, 'RSI_HIGH': 70}


# win 2 min


# wdo 5 min
{'sl': 8.0, 'tp': 6.0, 'LENGTH_RSI': 6, 'RSI_LOW': 0, 'RSI_HIGH': 0}

# wsp

# USDJPY 5 min
# Out:
# {'sl': 8.0, 'tp': 6.0, 'LENGTH_RSI': 6, 'RSI_LOW': 0, 'RSI_HIGH': 0}

# %%
params = {'sl': 500, 'tp': 200, 'LENGTH_RSI': 6, 'RSI_LOW': 30, 'RSI_HIGH': 30}
#params = {'sl': 5.0, 'tp': 2.5, 'period': 5, 'thres': 100.03}
#params = {'sl': 9.0, 'tp': 12.5, 'period': 5, 'thres': 10.080}
params = {'sl': 2000, 'tp': 800, 'period': 5, 'thres': 500.500}
params = {'sl': 300, 'tp': 700, 'period': 5, 'thres': 0.00}

# %%
# Configurar o backtester
sym = 'WIN@N'
#sym = 'WSP@N'
#sym = 'BIT@N'
#sym = 'WDO@N'
#sym = 'EURJPY'
#sym = 'GBPJPY'
#sym = 'USDJPY'



bt = Backtester(
    symbol = sym,
    timeframe = 't2',
    data_ini = '2019-01-01',
    data_fim = '2025-06-30',
    tp = params['tp'],
    sl = params['sl'],
    slippage = 0,
    tc = dict_custos[sym], # $ per lot
    lote = 1,
    valor_lote= dict_valor_lot[sym],
    initial_cash = 30000,
    path_base= dict_path[sym],
    daytrade = True
)


# Parâmetros da estratégia RSI
period = params['period']
thres = params['thres']

# Executa o backtest com a estratégia RSI
df, metrics = bt.run(
    signal_function=entrada, 
    signal_args={
        "period": period,
        "thres": thres,
        'allowed_hours': [9,10,11,12,13,14,15,16,17],
        #'allowed_hours': [12],
        'position_type': "both"
    }
)


# Print de métricas
bt.print_metrics(metrics)
# Out:
# ==================================================
# RELATÓRIO DE DESEMPENHO
# ==================================================
# Símbolo: WIN@N
# Timeframe: t2
# Período: 2019-01-01 a 2025-06-30
#
# --- RESULTADOS ---
# Saldo Inicial: $30000.00
# Saldo Final: $-8670.00
# Retorno Total: $-38670.00 (-128.90%)
# Retorno Anualizado: -14.13%
# Volatilidade Anualizada: 3414.90%
#
# --- DRAWDOWN ---
# Drawdown Máximo: 126.35%
# Drawdown Máximo (Valor): $47041.00
# Tempo Máximo em Drawdown: 276413.0 períodos
# Tempo em Drawdown: 98.98% do total
#
# --- TRADES ---
# Total de Trades: 21636
# Trades Vencedores: 7300 (33.74%)
# Trades Perdedores: 14307 (66.26%)
# Saídas por TP: 23.40%
# Saídas por SL: 60.43%
# Saídas por Tempo: 16.18%
#
# --- RATIOS ---
# Sharpe Ratio: -0.004
# Sortino Ratio: -0.037
# Calmar Ratio: -0.112
# Profit Factor: 0.954
#
# --- ANÁLISE DE GANHOS/PERDAS ---
# Ganho Médio: $109.91
# Perda Média: $58.79
# Win/Loss Ratio: 1.87
# Expectancy: $-1.87
# ==================================================

# %%
# Plotar a curva de equity com drawdown
plt.figure(figsize=(14, 10))

# 1. Curva de equity
plt = bt.plot_equity_curve(include_drawdown=True)

# 2. Análise detalhada de drawdown
plt = bt.plot_drawdown()

# 3. resultado por hora
bt.plot_by_position()
bt.plot_cumulative_by_hour()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\User\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#bt.plot_profit_by_hour()

# %% [markdown]
# # viz

# %%
df['vwap'] = df.ta.vwap(high='high', low='low', close='close', volume='volume')
df['v_minus_c'] = df['vwap'] - df['close']
df['pct_v_minus_c'] = (df['vwap'] - df['close'])/df['vwap']

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def plot_vwap_estrategia(df, start='2021-06-22', end='2021-06-26'):
    """
    Plota estratégia VWAP com gráfico de velas usando Plotly
    
    Args:
        df: DataFrame com colunas ['open', 'high', 'low', 'close', 'vwap', 'position']
        start: Data de início (string)
        end: Data de fim (string)
    """
    df_plot = df.loc[start:end].copy()
    
    # Cria o gráfico
    fig = go.Figure()
    
    # Adiciona gráfico de velas
    fig.add_trace(go.Candlestick(
        x=df_plot.index,
        open=df_plot['open'],
        high=df_plot['high'],
        low=df_plot['low'],
        close=df_plot['close'],
        name='Preço',
        increasing_line_color='green',
        decreasing_line_color='red'
    ))
    
    # Adiciona linha VWAP
    fig.add_trace(go.Scatter(
        x=df_plot.index,
        y=df_plot['vwap'],
        mode='lines',
        name='VWAP',
        line=dict(color='orange', dash='dash', width=2)
    ))
    
    # Marca entradas longas
    long_signals = df_plot[df_plot['position'] == 1]
    if not long_signals.empty:
        fig.add_trace(go.Scatter(
            x=long_signals.index,
            y=long_signals['close'],
            mode='markers',
            name='Entrada Long',
            marker=dict(
                symbol='triangle-up',
                size=12,
                color='green',
                line=dict(color='darkgreen', width=1)
            )
        ))
    
    # Marca entradas short
    short_signals = df_plot[df_plot['position'] == -1]
    if not short_signals.empty:
        fig.add_trace(go.Scatter(
            x=short_signals.index,
            y=short_signals['close'],
            mode='markers',
            name='Entrada Short',
            marker=dict(
                symbol='triangle-down',
                size=12,
                color='red',
                line=dict(color='darkred', width=1)
            )
        ))
    
    # Configurações do layout
    fig.update_layout(
        title=f'Estratégia VWAP com RSI | Período: {start} a {end}',
        xaxis_title='Data',
        yaxis_title='Preço',
        width=1200,
        height=600,
        showlegend=True,
        xaxis_rangeslider_visible=False,  # Remove o slider de range
        template='plotly_white'
    )
    
    # Configurações do grid
    fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgray')
    fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgray')
    
    fig.show()

# Versão alternativa com subplot para volume (caso você tenha dados de volume)
def plot_vwap_estrategia_com_volume(df, start='2021-06-22', end='2021-06-26'):
    """
    Versão com subplot para volume
    
    Args:
        df: DataFrame com colunas ['open', 'high', 'low', 'close', 'volume', 'vwap', 'position']
        start: Data de início (string)
        end: Data de fim (string)
    """
    df_plot = df.loc[start:end].copy()
    
    # Cria subplots
    fig = make_subplots(
        rows=2, cols=1,
        shared_xaxes=True,
        vertical_spacing=0.05,
        row_heights=[0.8, 0.2],
        subplot_titles=('Preço e VWAP', 'Volume')
    )
    
    # Gráfico de velas no subplot superior
    fig.add_trace(go.Candlestick(
        x=df_plot.index,
        open=df_plot['open'],
        high=df_plot['high'],
        low=df_plot['low'],
        close=df_plot['close'],
        name='Preço',
        increasing_line_color='green',
        decreasing_line_color='red'
    ), row=1, col=1)
    
    # VWAP
    fig.add_trace(go.Scatter(
        x=df_plot.index,
        y=df_plot['vwap'],
        mode='lines',
        name='VWAP',
        line=dict(color='orange', dash='dash', width=2)
    ), row=1, col=1)
    
    # Entradas longas
    long_signals = df_plot[df_plot['position'] == 1]
    if not long_signals.empty:
        fig.add_trace(go.Scatter(
            x=long_signals.index,
            y=long_signals['close'],
            mode='markers',
            name='Entrada Long',
            marker=dict(
                symbol='triangle-up',
                size=12,
                color='green',
                line=dict(color='darkgreen', width=1)
            )
        ), row=1, col=1)
    
    # Entradas short
    short_signals = df_plot[df_plot['position'] == -1]
    if not short_signals.empty:
        fig.add_trace(go.Scatter(
            x=short_signals.index,
            y=short_signals['close'],
            mode='markers',
            name='Entrada Short',
            marker=dict(
                symbol='triangle-down',
                size=12,
                color='red',
                line=dict(color='darkred', width=1)
            )
        ), row=1, col=1)
    
    # Volume no subplot inferior (se existir)
    if 'volume' in df_plot.columns:
        fig.add_trace(go.Bar(
            x=df_plot.index,
            y=df_plot['volume'],
            name='Volume',
            marker_color='blue',
            opacity=0.7
        ), row=2, col=1)
    
    # Layout
    fig.update_layout(
        title=f'Estratégia VWAP com RSI | Período: {start} a {end}',
        width=1200,
        height=800,
        showlegend=True,
        xaxis_rangeslider_visible=False,
        template='plotly_white'
    )
    
    # Labels dos eixos
    fig.update_yaxes(title_text="Preço", row=1, col=1)
    fig.update_yaxes(title_text="Volume", row=2, col=1)
    fig.update_xaxes(title_text="Data", row=2, col=1)
    
    # Grid
    fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgray')
    fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgray')
    
    fig.show()

# %%
def plot_vwap_estrategia_com_volume_e_lucro(df, start='2021-06-22', end='2021-06-26'):
    """
    Versão com subplots para volume e lucro acumulado
    
    Args:
        df: DataFrame com colunas ['open', 'high', 'low', 'close', 'volume', 'vwap', 'position', 'strategy']
        start: Data de início (string)
        end: Data de fim (string)
    """
    df_plot = df.loc[start:end].copy()
    
    # Calcula lucro acumulado
    df_plot['lucro_acumulado'] = df_plot['strategy'].cumsum()
    
    # Cria subplots com 3 linhas
    fig = make_subplots(
        rows=3, cols=1,
        shared_xaxes=True,
        vertical_spacing=0.03,
        row_heights=[0.6, 0.2, 0.2],
        subplot_titles=('Preço e VWAP', 'Volume', 'Lucro Acumulado')
    )
    
    # Gráfico de velas no subplot superior
    fig.add_trace(go.Candlestick(
        x=df_plot.index,
        open=df_plot['open'],
        high=df_plot['high'],
        low=df_plot['low'],
        close=df_plot['close'],
        name='Preço',
        increasing_line_color='green',
        decreasing_line_color='red'
    ), row=1, col=1)
    
    # VWAP
    fig.add_trace(go.Scatter(
        x=df_plot.index,
        y=df_plot['vwap'],
        mode='lines',
        name='VWAP',
        line=dict(color='orange', dash='dash', width=2)
    ), row=1, col=1)
    
    # Entradas longas
    long_signals = df_plot[df_plot['position'] == 1]
    if not long_signals.empty:
        fig.add_trace(go.Scatter(
            x=long_signals.index,
            y=long_signals['close'],
            mode='markers',
            name='Entrada Long',
            marker=dict(
                symbol='triangle-up',
                size=12,
                color='green',
                line=dict(color='darkgreen', width=1)
            )
        ), row=1, col=1)
    
    # Entradas short
    short_signals = df_plot[df_plot['position'] == -1]
    if not short_signals.empty:
        fig.add_trace(go.Scatter(
            x=short_signals.index,
            y=short_signals['close'],
            mode='markers',
            name='Entrada Short',
            marker=dict(
                symbol='triangle-down',
                size=12,
                color='red',
                line=dict(color='darkred', width=1)
            )
        ), row=1, col=1)
    
    # Volume no segundo subplot (se existir)
    if 'volume' in df_plot.columns:
        fig.add_trace(go.Bar(
            x=df_plot.index,
            y=df_plot['volume'],
            name='Volume',
            marker_color='blue',
            opacity=0.7,
            showlegend=False
        ), row=2, col=1)
    
    # Lucro acumulado no terceiro subplot
    fig.add_trace(go.Scatter(
        x=df_plot.index,
        y=df_plot['lucro_acumulado'],
        mode='lines',
        name='Lucro Acumulado',
        line=dict(color='purple', width=2),
        fill='tonexty' if df_plot['lucro_acumulado'].iloc[0] >= 0 else None,
        showlegend=True
    ), row=3, col=1)
    
    # Linha zero para referência no lucro acumulado
    fig.add_hline(y=0, line_dash="dash", line_color="gray", 
                  opacity=0.5, row=3, col=1)
    
    # Layout
    fig.update_layout(
        title=f'Estratégia VWAP com RSI | Período: {start} a {end}',
        width=1200,
        height=1000,
        showlegend=True,
        xaxis_rangeslider_visible=False,
        template='plotly_white'
    )
    
    # Labels dos eixos
    fig.update_yaxes(title_text="Preço", row=1, col=1)
    fig.update_yaxes(title_text="Volume", row=2, col=1)
    fig.update_yaxes(title_text="Lucro Acumulado", row=3, col=1)
    fig.update_xaxes(title_text="Data", row=3, col=1)
    
    # Grid
    fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgray')
    fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgray')
    
    # Calcula e mostra estatísticas do lucro
    lucro_total = df_plot['lucro_acumulado'].iloc[-1]
    lucro_maximo = df_plot['lucro_acumulado'].max()
    lucro_minimo = df_plot['lucro_acumulado'].min()
    
    print(f"Estatísticas do Período ({start} a {end}):")
    print(f"Lucro Total: {lucro_total:.4f}")
    print(f"Lucro Máximo: {lucro_maximo:.4f}")
    print(f"Lucro Mínimo: {lucro_minimo:.4f}")
    print(f"Drawdown Máximo: {lucro_maximo - lucro_minimo:.4f}")
    
    fig.show()

# %%
plot_vwap_estrategia_com_volume_e_lucro(df, start='2024-06-05', end='2024-06-26')
# Out:
# Estatísticas do Período (2024-06-05 a 2024-06-26):
# Lucro Total: -203.0000
# Lucro Máximo: 162.0000
# Lucro Mínimo: -372.0000
# Drawdown Máximo: 534.0000
# <div>                            <div id="660efeee-f207-42c0-a86d-5fe073c60514" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("660efeee-f207-42c0-a86d-5fe073c60514")) {                    Plotly.newPlot(                        "660efeee-f207-42c0-a86d-5fe073c60514",                        [{"close":[122075.0,122055.0,122115.0,122110.0,122100.0,121970.0,121930.0,121905.0,121930.0,121905.0,121905.0,121950.0,121850.0,121880.0,121880.0,121910.0,121910.0,121985.0,121810.0,121805.0,121900.0,121805.0,121800.0,121970.0,121735.0,121615.0,121500.0,121525.0,121740.0,121765.0,122005.0,122265.0,122290.0,122095.0,122095.0,122060.0,122145.0,122060.0,122055.0,122230.0,122260.0,122270.0,122220.0,122210.0,122195.0,122165.0,122125.0,122155.0,122120.0,122040.0,122040.0,122050.0,122025.0,121905.0,121895.0,121940.0,121925.0,121885.0,122030.0,121930.0,121945.0,121895.0,121835.0,121865.0,121865.0,121930.0,122000.0,121975.0,122040.0,121910.0,121745.0,121770.0,121825.0,121715.0,121585.0,121565.0,121585.0,121555.0,121540.0,121480.0,121525.0,121485.0,121610.0,121610.0,121635.0,121545.0,121480.0,121510.0,121565.0,121535.0,121495.0,121560.0,121565.0,121550.0,121580.0,121650.0,121600.0,121535.0,121505.0,121620.0,121580.0,121590.0,121610.0,121555.0,121550.0,121595.0,121580.0,121585.0,121575.0,121565.0,121585.0,121550.0,121515.0,121590.0,121530.0,121645.0,121650.0,121510.0,121545.0,121465.0,121470.0,121485.0,121620.0,121645.0,121710.0,121685.0,121645.0,121615.0,121720.0,122135.0,122455.0,122645.0,122765.0,122650.0,122470.0,122405.0,122510.0,122520.0,122585.0,122460.0,122385.0,122360.0,122510.0,122695.0,122745.0,122630.0,122680.0,122755.0,122720.0,122745.0,122885.0,122970.0,123085.0,123230.0,123260.0,123250.0,123340.0,123420.0,123270.0,123345.0,123345.0,123095.0,123105.0,123125.0,123165.0,123095.0,123125.0,123025.0,122990.0,122930.0,122925.0,122975.0,123020.0,123095.0,123055.0,123040.0,123090.0,123320.0,123240.0,123315.0,123320.0,123360.0,123185.0,123090.0,123145.0,123085.0,122905.0,122945.0,123065.0,123115.0,123105.0,123130.0,123155.0,123200.0,123240.0,123110.0,123060.0,122970.0,123020.0,122990.0,122970.0,122950.0,122930.0,122910.0,122935.0,123060.0,123125.0,123150.0,123185.0,123145.0,123100.0,123130.0,123150.0,123145.0,123115.0,123175.0,123170.0,123135.0,123130.0,123180.0,123160.0,123180.0,123185.0,123255.0,123185.0,123005.0,122910.0,122905.0,123085.0,123170.0,123090.0,123210.0,121920.0,122125.0,121800.0,121875.0,121750.0,121855.0,121825.0,121885.0,121865.0,122155.0,122050.0,121875.0,121770.0,121825.0,121915.0,121915.0,122000.0,121985.0,122025.0,122155.0,122140.0,122305.0,122080.0,122250.0,122220.0,122265.0,122230.0,122110.0,122120.0,122135.0,122050.0,122085.0,122020.0,122005.0,122095.0,122120.0,122075.0,122070.0,122010.0,122000.0,121925.0,121875.0,121980.0,122060.0,122020.0,121910.0,121975.0,122040.0,121850.0,121830.0,121850.0,121705.0,121800.0,121860.0,121760.0,121740.0,121800.0,121840.0,121740.0,121640.0,121705.0,121755.0,121655.0,121555.0,121505.0,121520.0,121430.0,121360.0,121390.0,121510.0,121480.0,121550.0,121530.0,121550.0,121485.0,121350.0,121345.0,121250.0,121255.0,120950.0,120765.0,120875.0,120845.0,120925.0,121035.0,120940.0,120820.0,120795.0,120835.0,120850.0,120865.0,120860.0,120785.0,120815.0,120950.0,120875.0,120885.0,120855.0,120765.0,120720.0,120760.0,120760.0,120715.0,120645.0,120620.0,120535.0,120605.0,121315.0,121290.0,121210.0,121195.0,121195.0,121170.0,121140.0,121095.0,121045.0,120975.0,121010.0,121005.0,120900.0,120560.0,120570.0,120725.0,120790.0,120815.0,120940.0,121030.0,121170.0,121320.0,121245.0,121075.0,121090.0,121070.0,121150.0,121255.0,121355.0,121265.0,121240.0,121235.0,121335.0,121330.0,121445.0,121215.0,121265.0,121255.0,121175.0,121210.0,121175.0,121160.0,121060.0,121125.0,121125.0, ...

# %%
df['v_minus_c'].loc['2019-06-01':'2025-06-26'].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# # Cruzando com indicadores

# %%
def plot_rsi_profit(compr, nquantis, df, direction='both'):
    
    df2 = df.copy()
    
    df2['rsi'] = df2.ta.rsi(length=compr)
    df2['rsi'] = df2['rsi'].fillna(0)
    df2['bin_rsi'] = pd.qcut(df2['rsi'], nquantis)   

    if direction=='both':
        pass    
    elif direction=='long':
        df2.loc[df2['position']==-1, 'strategy'] = 0    
    elif direction=='short':
        df2.loc[df2['position']==+1, 'strategy'] = 0    
    
    df2['cstrategy'] = df2['strategy'].cumsum()
    for hora in df2.index.hour.unique():
        df2['strategy_'+str(hora)] = 0.0
        df2.loc[df2.index.hour==hora,'strategy_'+str(hora)] = df2[df2.index.hour==hora]['strategy']
        df2['cstrategy_'+str(hora)] = df2['strategy_'+str(hora)].cumsum()

    colunas = [ 'bin_rsi','strategy', 'strategy_9','strategy_10','strategy_11','strategy_12','strategy_13',
              'strategy_14','strategy_15','strategy_16','strategy_17']

    # Dataframe com RSI e retornos médios por operação
    dfrsi = df2[df2['position']!=0][colunas].groupby(['bin_rsi'], observed=True).mean().round(2)

    #Plot
    dfrsi.iloc[:,1:].plot(kind='bar',figsize = (10,6))

# %%
def plot_adx_profit(compr, nquantis, df, direction='both'):
    
    df2 = df.copy()
    
    df2['rsi'] = df2.ta.rsi(length=compr)
    df2['adx'] = df2.ta.adx(length=compr)['ADX_'+str(compr)]
    df2['bin_rsi'] = pd.qcut(df2['adx'], nquantis)   

    if direction=='both':
        pass    
    elif direction=='long':
        df2.loc[df2['position']==-1, 'strategy'] = 0    
    elif direction=='short':
        df2.loc[df2['position']==+1, 'strategy'] = 0    
    
    df2['cstrategy'] = df2['strategy'].cumsum()
    for hora in df2.index.hour.unique():
        df2['strategy_'+str(hora)] = 0.0
        df2.loc[df2.index.hour==hora,'strategy_'+str(hora)] = df2[df2.index.hour==hora]['strategy']
        df2['cstrategy_'+str(hora)] = df2['strategy_'+str(hora)].cumsum()

    colunas = [ 'bin_rsi','strategy', 'strategy_9','strategy_10','strategy_11','strategy_12','strategy_13',
              'strategy_14','strategy_15','strategy_16','strategy_17']

    # Dataframe com RSI e retornos médios por operação
    dfrsi = df2[df2['position']!=0][colunas].groupby(['bin_rsi'], observed=True).mean().round(2)

    #Plot
    dfrsi.iloc[:,1:].plot(kind='bar',figsize = (10,6))

# %%
compr = 4
nquantis = 8
plot_rsi_profit(compr, nquantis, df, direction='short')

# %%
compr = 4
nquantis = 8
plot_rsi_profit(compr, nquantis, df, direction='long')

# %%
compr = 4
nquantis = 8
plot_adx_profit(compr, nquantis, df, direction='both')

# %% [markdown]
# # Otimização

# %%
metrics
# Out:
# {'initial_cash': 30000,
#  'final_equity': 148663.0,
#  'total_return': 118663.0,
#  'total_return_pct': 395.54333333333335,
#  'annual_return': 31.44768159985931,
#  'annual_volatility': 19.604626512650096,
#  'total_trades': 4524,
#  'win_trades': 1342,
#  'loss_trades': 3181,
#  'win_rate': 0.29664014146772766,
#  'tp_rate': 0.1275419982316534,
#  'sl_rate': 0.6821396993810787,
#  'time_exit_rate': 0.1903183023872679,
#  'profit_factor': 1.3223793417281335,
#  'max_drawdown': 0.5930061091215505,
#  'max_drawdown_value': 8000.0,
#  'max_time_underwater': 14470.0,
#  'underwater_rate': 0.9632069316790093,
#  'sharpe_ratio': 1.6040949099217656,
#  'sortino_ratio': 6.519152395982275,
#  'calmar_ratio': 0.5303095721297767,
#  'avg_win': 362.70342771982115,
#  'avg_loss': 115.71361207167557,
#  'win_loss_ratio': 3.13449231448375,
#  'expectancy': 26.204086292645513,
#  'risk_free_rate': 0.0}

# %%
def objective_ind(trial):  
    
    '''
    função para maximizar os ganhos no mini-indice
    '''

    # Configurar o backtester
    sym = 'WSP@N'
    
    bt = Backtester(
        symbol = sym,
        timeframe = 't5',
        data_ini = '2019-01-01',
        data_fim = '2025-12-31',
        sl = trial.suggest_int('sl', 1, 35),
        tp = trial.suggest_int('tp', 1, 35),
        slippage = 0,
        tc = dict_custos[sym], # $ per lot
        lote = 1,
        valor_lote= dict_valor_lot[sym],
        initial_cash = 30000,
        path_base= dict_path[sym],
        daytrade = True
    )
    
    # Parâmetros da estratégia RSI
    LENGTH_RSI = trial.suggest_int('LENGTH_RSI', 4, 16)
    RSI_LOW = trial.suggest_int('RSI_LOW', 20, 50)
    RSI_HIGH = trial.suggest_int('RSI_HIGH', 50, 80)
    
    # Executa o backtest com a estratégia RSI
    _, metrics = bt.run(
        signal_function=entrada, 
        signal_args={
            "length_rsi": LENGTH_RSI,
            "rsi_low": RSI_LOW,
            "rsi_high": RSI_HIGH,
            'allowed_hours': [10,11,12,13]
        }
    )

    
    metrica = metrics['sharpe_ratio']
    #metrica = metrics['max_drawdown_value']
        
    return metrica

# %%
study = optuna.create_study(direction="maximize")

study.optimize(objective_ind, n_trials=220)
# Out:
# [I 2025-06-28 20:55:10,122] A new study created in memory with name: no-name-fde9fa91-cd99-40fc-9bca-cd8eb338fcfa
# [I 2025-06-28 20:55:10,810] Trial 0 finished with value: -0.11641332847268865 and parameters: {'sl': 33, 'tp': 29, 'LENGTH_RSI': 4, 'RSI_LOW': 29, 'RSI_HIGH': 60}. Best is trial 0 with value: -0.11641332847268865.
# [I 2025-06-28 20:55:11,498] Trial 1 finished with value: 0.28204632710868577 and parameters: {'sl': 10, 'tp': 24, 'LENGTH_RSI': 15, 'RSI_LOW': 40, 'RSI_HIGH': 60}. Best is trial 1 with value: 0.28204632710868577.
# [I 2025-06-28 20:55:12,185] Trial 2 finished with value: -0.27924258255615597 and parameters: {'sl': 35, 'tp': 15, 'LENGTH_RSI': 10, 'RSI_LOW': 34, 'RSI_HIGH': 55}. Best is trial 1 with value: 0.28204632710868577.
# [I 2025-06-28 20:55:12,890] Trial 3 finished with value: 0.7490335688009492 and parameters: {'sl': 28, 'tp': 18, 'LENGTH_RSI': 10, 'RSI_LOW': 25, 'RSI_HIGH': 68}. Best is trial 3 with value: 0.7490335688009492.
# [I 2025-06-28 20:55:13,590] Trial 4 finished with value: -0.11779911847735886 and parameters: {'sl': 32, 'tp': 28, 'LENGTH_RSI': 12, 'RSI_LOW': 32, 'RSI_HIGH': 80}. Best is trial 3 with value: 0.7490335688009492.
# [I 2025-06-28 20:55:14,300] Trial 5 finished with value: 0.6488476132838102 and parameters: {'sl': 32, 'tp': 33, 'LENGTH_RSI': 14, 'RSI_LOW': 24, 'RSI_HIGH': 51}. Best is trial 3 with value: 0.7490335688009492.
# [I 2025-06-28 20:55:15,003] Trial 6 finished with value: -0.02953760114839702 and parameters: {'sl': 4, 'tp': 9, 'LENGTH_RSI': 10, 'RSI_LOW': 47, 'RSI_HIGH': 58}. Best is trial 3 with value: 0.7490335688009492.
# [I 2025-06-28 20:55:15,717] Trial 7 finished with value: 0.13009923819898747 and parameters: {'sl': 11, 'tp': 24, 'LENGTH_RSI': 4, 'RSI_LOW': 25, 'RSI_HIGH': 75}. Best is trial 3 with value: 0.7490335688009492.
# [I 2025-06-28 20:55:16,410] Trial 8 finished with value: 0.5524338862902971 and parameters: {'sl': 17, 'tp': 23, 'LENGTH_RSI': 8, 'RSI_LOW': 27, 'RSI_HIGH': 69}. Best is trial 3 with value: 0.7490335688009492.
# [I 2025-06-28 20:55:17,097] Trial 9 finished with value: 0.1795817148244468 and parameters: {'sl': 26, 'tp': 25, 'LENGTH_RSI': 5, 'RSI_LOW': 25, 'RSI_HIGH': 59}. Best is trial 3 with value: 0.7490335688009492.
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\numpy\core\_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# [I 2025-06-28 20:55:17,798] Trial 10 finished with value: -0.21494444277160585 and parameters: {'sl': 23, 'tp': 1, 'LENGTH_RSI': 7, 'RSI_LOW': 20, 'RSI_HIGH': 68}. Best is trial 3 with value: 0.7490335688009492.
# [I 2025-06-28 20:55:18,525] Trial 11 finished with value: 0.14995069296464872 and parameters: {'sl': 26, 'tp': 17, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 50}. Best is trial 3 with value: 0.7490335688009492.
# [I 2025-06-28 20:55:19,233] Trial 12 finished with value: 0.20998114791106418 and parameters: {'sl': 29, 'tp': 34, 'LENGTH_RSI': 13, 'RSI_LOW': 38, 'RSI_HIGH': 66}. Best is trial 3 with value: 0.7490335688009492.
# [I 2025-06-28 20:55:19,950] Trial 13 finished with value: 0.7702177114532452 and parameters: {'sl': 20, 'tp': 35, 'LENGTH_RSI': 12, 'RSI_LOW': 22, 'RSI_HIGH': 74}. Best is trial 13 with value: 0.7702177114532452.
# [I 2025-06-28 20:55:20,645] Trial 14 finished with value: -0.4675207010863872 and parameters: {'sl': 19, 'tp': 10, 'LENGTH_RSI': 11, 'RSI_LOW': 30, 'RSI_HIGH': 73}. Best is trial 13 with value: 0.7702177114532452.
# [I 2025-06-28 20:55:21,330] Trial 15 finished with value: 0.5029930830588063 and parameters: {'sl': 18, 'tp': 19, 'LENGTH_RSI': 8, 'RSI_LOW': 22, 'RSI_HIGH': 74}. Best is trial 13 with value: 0.7702177114532452.
# [I 2025-06-28 20:55:22,030] Trial 16 finished with value: -0.0007812640741560968 and parameters: {'sl': 22, 'tp': 9, 'LENGTH_RSI': 12, 'RSI_LOW': 46, 'RSI_HIGH': 80}. Best is trial 13 with value: 0.7702177114532452.
# [I 2025-06-28 20:55:22,713] Trial 17 finished with value: -0.2718173322473205 and parameters: {'sl': 14, 'tp': 20, 'LENGTH_RSI': 9, 'RSI_LOW': 37, 'RSI_HIGH': 71}. Best is trial 13 with value: 0.7702177114532452.
# [I 2025-06-28 20:55:23,425] Trial 18 finished with value: -1.279131091841449 and parameters: {'sl': 2, 'tp': 14, 'LENGTH_RSI': 6, 'RSI_LOW': 28, 'RSI_HIGH': 65}. Best is trial 13 with value: 0.7702177114532452.
# [I 2025-06-28 20:55:24,154] Trial 19 finished with value: -0.06694809715072962 and parameters: {'sl': 27, 'tp': 4, 'LENGTH_RSI': 13, 'RSI_LOW': 50, 'RSI_HIGH': 77}. Best is trial 13 with value: 0.7702177114532452.
# [I 2025-06-28 20:55:24,820] Trial 20 finished with value: 0.4607085291670772 and parameters: {'sl': 22, 'tp': 29, 'LENGTH_RSI': 16, 'RSI_LOW': 23, 'RSI_HIGH': 71}. Best is trial 13 with value: 0.7702177114532452.
# [I 2025-06-28 20:55:25,486] Trial 21 finished with value: 0.9119952089313769 and parameters: {'sl': 28, 'tp': 33, 'LENGTH_RSI': 13, 'RSI_LOW': 24, 'RSI_HIGH': 64}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:26,134] Trial 22 finished with value: 0.8811546986219756 and parameters: {'sl': 30, 'tp': 35, 'LENGTH_RSI': 11, 'RSI_LOW': 26, 'RSI_HIGH': 64}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:26,783] Trial 23 finished with value: 0.7194486525462122 and parameters: {'sl': 30, 'tp': 35, 'LENGTH_RSI': 12, 'RSI_LOW': 32, 'RSI_HIGH': 63}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:27,430] Trial 24 finished with value: 0.8935480361459972 and parameters: {'sl': 23, 'tp': 32, 'LENGTH_RSI': 11, 'RSI_LOW': 22, 'RSI_HIGH': 64}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:28,076] Trial 25 finished with value: 0.7351226296813583 and parameters: {'sl': 24, 'tp': 30, 'LENGTH_RSI': 11, 'RSI_LOW': 27, 'RSI_HIGH': 63}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:28,722] Trial 26 finished with value: 0.8562289871869109 and parameters: {'sl': 35, 'tp': 32, 'LENGTH_RSI': 13, 'RSI_LOW': 20, 'RSI_HIGH': 63}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:29,378] Trial 27 finished with value: 0.5445886752531098 and parameters: {'sl': 30, 'tp': 31, 'LENGTH_RSI': 11, 'RSI_LOW': 27, 'RSI_HIGH': 56}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:30,020] Trial 28 finished with value: 0.48512522970335714 and parameters: {'sl': 26, 'tp': 27, 'LENGTH_RSI': 9, 'RSI_LOW': 31, 'RSI_HIGH': 62}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:30,640] Trial 29 finished with value: 0.8409276868577086 and parameters: {'sl': 32, 'tp': 32, 'LENGTH_RSI': 14, 'RSI_LOW': 29, 'RSI_HIGH': 66}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:31,286] Trial 30 finished with value: -0.14265980975425005 and parameters: {'sl': 24, 'tp': 27, 'LENGTH_RSI': 9, 'RSI_LOW': 42, 'RSI_HIGH': 61}. Best is trial 21 with value: 0.9119952089313769.
# [I 2025-06-28 20:55:31,932] Trial 31 finished with value: 0.94871994551269 and parameters: {'sl': 34, 'tp': 32, 'LENGTH_RSI': 13, 'RSI_LOW': 20, 'RSI_HIGH': 64}. Best is trial 31 with value: 0.94871994551269.
# [I 2025-06-28 20:55:32,570] Trial 32 finished with value: 0.9656283818098413 and parameters: {'sl': 33, 'tp': 30, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 65}. Best is trial 32 with value: 0.9656283818098413.
# [I 2025-06-28 20:55:33,205] Trial 33 finished with value: 0.75274126009718 and parameters: {'sl': 35, 'tp': 30, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 67}. Best is trial 32 with value: 0.9656283818098413.
# [I 2025-06-28 20:55:33,840] Trial 34 finished with value: 0.587583149303114 and parameters: {'sl': 33, 'tp': 26, 'LENGTH_RSI': 16, 'RSI_LOW': 23, 'RSI_HIGH': 60}. Best is trial 32 with value: 0.9656283818098413.
# [I 2025-06-28 20:55:34,475] Trial 35 finished with value: 0.6099251425953044 and parameters: {'sl': 33, 'tp': 32, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 57}. Best is trial 32 with value: 0.9656283818098413.
# [I 2025-06-28 20:55:35,107] Trial 36 finished with value: 0.8869608358728941 and parameters: {'sl': 28, 'tp': 29, 'LENGTH_RSI': 15, 'RSI_LOW': 24, 'RSI_HIGH': 65}. Best is trial 32 with value: 0.9656283818098413.
# [I 2025-06-28 20:55:35,735] Trial 37 finished with value: -0.06965800671969458 and parameters: {'sl': 35, 'tp': 22, 'LENGTH_RSI': 13, 'RSI_LOW': 34, 'RSI_HIGH': 70}. Best is trial 32 with value: 0.9656283818098413.
# [I 2025-06-28 20:55:36,375] Trial 38 finished with value: 0.7048321499600169 and parameters: {'sl': 30, 'tp': 28, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 61}. Best is trial 32 with value: 0.9656283818098413.
# [I 2025-06-28 20:55:37,020] Trial 39 finished with value: 0.6067383710914115 and parameters: {'sl': 32, 'tp': 32, 'LENGTH_RSI': 12, 'RSI_LOW': 24, 'RSI_HIGH': 54}. Best is trial 32 with value: 0.9656283818098413.
# [I 2025-06-28 20:55:37,647] Trial 40 finished with value: 1.0953715436316875 and parameters: {'sl': 15, 'tp': 33, 'LENGTH_RSI': 14, 'RSI_LOW': 26, 'RSI_HIGH': 68}. Best is trial 40 with value: 1.0953715436316875.
# [I 2025-06-28 20:55:38,275] Trial 41 finished with value: 1.1778383159350083 and parameters: {'sl': 16, 'tp': 33, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 68}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:38,911] Trial 42 finished with value: 1.0639658343729106 and parameters: {'sl': 15, 'tp': 34, 'LENGTH_RSI': 14, 'RSI_LOW': 25, 'RSI_HIGH': 69}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:39,560] Trial 43 finished with value: 1.0533040247323018 and parameters: {'sl': 15, 'tp': 34, 'LENGTH_RSI': 16, 'RSI_LOW': 26, 'RSI_HIGH': 68}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:40,203] Trial 44 finished with value: 0.9666904396679601 and parameters: {'sl': 15, 'tp': 34, 'LENGTH_RSI': 16, 'RSI_LOW': 26, 'RSI_HIGH': 69}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:40,847] Trial 45 finished with value: 0.8509286025478551 and parameters: {'sl': 15, 'tp': 34, 'LENGTH_RSI': 16, 'RSI_LOW': 29, 'RSI_HIGH': 69}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:41,502] Trial 46 finished with value: 0.9976126556116999 and parameters: {'sl': 8, 'tp': 34, 'LENGTH_RSI': 15, 'RSI_LOW': 26, 'RSI_HIGH': 72}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:42,128] Trial 47 finished with value: 0.27425528919549935 and parameters: {'sl': 8, 'tp': 35, 'LENGTH_RSI': 15, 'RSI_LOW': 33, 'RSI_HIGH': 72}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:42,757] Trial 48 finished with value: 1.107779254056179 and parameters: {'sl': 13, 'tp': 33, 'LENGTH_RSI': 15, 'RSI_LOW': 26, 'RSI_HIGH': 68}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:43,449] Trial 49 finished with value: 0.8282803527733577 and parameters: {'sl': 11, 'tp': 28, 'LENGTH_RSI': 15, 'RSI_LOW': 30, 'RSI_HIGH': 68}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:44,110] Trial 50 finished with value: 0.9531617418490591 and parameters: {'sl': 13, 'tp': 23, 'LENGTH_RSI': 16, 'RSI_LOW': 28, 'RSI_HIGH': 67}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:44,770] Trial 51 finished with value: 0.8475698427842313 and parameters: {'sl': 9, 'tp': 33, 'LENGTH_RSI': 15, 'RSI_LOW': 26, 'RSI_HIGH': 71}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:45,440] Trial 52 finished with value: 0.9720667670761612 and parameters: {'sl': 6, 'tp': 30, 'LENGTH_RSI': 14, 'RSI_LOW': 25, 'RSI_HIGH': 75}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:46,104] Trial 53 finished with value: 0.6862660874452308 and parameters: {'sl': 17, 'tp': 34, 'LENGTH_RSI': 14, 'RSI_LOW': 28, 'RSI_HIGH': 70}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:46,729] Trial 54 finished with value: 0.9841683513252515 and parameters: {'sl': 12, 'tp': 33, 'LENGTH_RSI': 15, 'RSI_LOW': 25, 'RSI_HIGH': 73}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:47,368] Trial 55 finished with value: 1.1074405425142833 and parameters: {'sl': 16, 'tp': 31, 'LENGTH_RSI': 16, 'RSI_LOW': 27, 'RSI_HIGH': 67}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:48,030] Trial 56 finished with value: 0.4625733994412 and parameters: {'sl': 16, 'tp': 31, 'LENGTH_RSI': 16, 'RSI_LOW': 36, 'RSI_HIGH': 67}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:48,671] Trial 57 finished with value: 0.6202569749724693 and parameters: {'sl': 18, 'tp': 25, 'LENGTH_RSI': 16, 'RSI_LOW': 30, 'RSI_HIGH': 68}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:49,303] Trial 58 finished with value: 1.0210941691431346 and parameters: {'sl': 20, 'tp': 35, 'LENGTH_RSI': 14, 'RSI_LOW': 23, 'RSI_HIGH': 66}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:49,952] Trial 59 finished with value: -0.5476046410751483 and parameters: {'sl': 13, 'tp': 14, 'LENGTH_RSI': 15, 'RSI_LOW': 40, 'RSI_HIGH': 70}. Best is trial 41 with value: 1.1778383159350083.
# [I 2025-06-28 20:55:50,599] Trial 60 finished with value: 1.1941093324643106 and parameters: {'sl': 16, 'tp': 29, 'LENGTH_RSI': 16, 'RSI_LOW': 21, 'RSI_HIGH': 77}. Best is trial 60 with value: 1.1941093324643106.
# [I 2025-06-28 20:55:51,254] Trial 61 finished with value: 1.1441846232658333 and parameters: {'sl': 16, 'tp': 31, 'LENGTH_RSI': 16, 'RSI_LOW': 21, 'RSI_HIGH': 76}. Best is trial 60 with value: 1.1941093324643106.
# [I 2025-06-28 20:55:51,917] Trial 62 finished with value: 0.9735350224971117 and parameters: {'sl': 17, 'tp': 29, 'LENGTH_RSI': 16, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 60 with value: 1.1941093324643106.
# [I 2025-06-28 20:55:52,573] Trial 63 finished with value: 0.8899598213485052 and parameters: {'sl': 20, 'tp': 31, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 76}. Best is trial 60 with value: 1.1941093324643106.
# [I 2025-06-28 20:55:53,233] Trial 64 finished with value: 0.4682939346984587 and parameters: {'sl': 14, 'tp': 31, 'LENGTH_RSI': 4, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 60 with value: 1.1941093324643106.
# [I 2025-06-28 20:55:53,895] Trial 65 finished with value: 0.7292118012540775 and parameters: {'sl': 19, 'tp': 29, 'LENGTH_RSI': 13, 'RSI_LOW': 23, 'RSI_HIGH': 77}. Best is trial 60 with value: 1.1941093324643106.
# [I 2025-06-28 20:55:54,532] Trial 66 finished with value: 0.5767646763075678 and parameters: {'sl': 16, 'tp': 27, 'LENGTH_RSI': 16, 'RSI_LOW': 24, 'RSI_HIGH': 74}. Best is trial 60 with value: 1.1941093324643106.
# [I 2025-06-28 20:55:55,179] Trial 67 finished with value: 1.5254773492043867 and parameters: {'sl': 11, 'tp': 11, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 67 with value: 1.5254773492043867.
# [I 2025-06-28 20:55:55,825] Trial 68 finished with value: 0.27685358210234057 and parameters: {'sl': 11, 'tp': 7, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 80}. Best is trial 67 with value: 1.5254773492043867.
# [I 2025-06-28 20:55:56,459] Trial 69 finished with value: 1.4724494023099002 and parameters: {'sl': 12, 'tp': 16, 'LENGTH_RSI': 16, 'RSI_LOW': 23, 'RSI_HIGH': 78}. Best is trial 67 with value: 1.5254773492043867.
# [I 2025-06-28 20:55:57,093] Trial 70 finished with value: 2.4002765692720347 and parameters: {'sl': 13, 'tp': 12, 'LENGTH_RSI': 16, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:55:57,730] Trial 71 finished with value: 1.1163756676191094 and parameters: {'sl': 10, 'tp': 11, 'LENGTH_RSI': 16, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:55:58,363] Trial 72 finished with value: 1.4789319272193127 and parameters: {'sl': 10, 'tp': 12, 'LENGTH_RSI': 16, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:55:58,984] Trial 73 finished with value: 1.0043177831581938 and parameters: {'sl': 10, 'tp': 12, 'LENGTH_RSI': 16, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:55:59,615] Trial 74 finished with value: 1.1884717492061907 and parameters: {'sl': 5, 'tp': 16, 'LENGTH_RSI': 16, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:00,272] Trial 75 finished with value: 0.602535105881546 and parameters: {'sl': 2, 'tp': 17, 'LENGTH_RSI': 16, 'RSI_LOW': 21, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:00,890] Trial 76 finished with value: -0.9939691811786479 and parameters: {'sl': 4, 'tp': 13, 'LENGTH_RSI': 6, 'RSI_LOW': 23, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:01,525] Trial 77 finished with value: 1.242447707349667 and parameters: {'sl': 6, 'tp': 16, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:02,144] Trial 78 finished with value: 0.7258543263360462 and parameters: {'sl': 5, 'tp': 16, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:02,765] Trial 79 finished with value: 1.3087894548510655 and parameters: {'sl': 7, 'tp': 19, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:03,411] Trial 80 finished with value: 1.3087894548510655 and parameters: {'sl': 7, 'tp': 19, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:04,055] Trial 81 finished with value: 1.4541103913922193 and parameters: {'sl': 7, 'tp': 21, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:04,695] Trial 82 finished with value: 1.3463181611966035 and parameters: {'sl': 7, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:05,325] Trial 83 finished with value: 1.5574405996767768 and parameters: {'sl': 7, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:05,955] Trial 84 finished with value: 1.5547264396522469 and parameters: {'sl': 8, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:06,569] Trial 85 finished with value: 1.5403051494837674 and parameters: {'sl': 9, 'tp': 21, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 75}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:07,196] Trial 86 finished with value: 1.2215073170076418 and parameters: {'sl': 9, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 23, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:07,824] Trial 87 finished with value: 1.5208994631974126 and parameters: {'sl': 9, 'tp': 21, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 75}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:08,454] Trial 88 finished with value: -0.7469446246526815 and parameters: {'sl': 9, 'tp': 8, 'LENGTH_RSI': 10, 'RSI_LOW': 22, 'RSI_HIGH': 75}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:09,080] Trial 89 finished with value: 1.0860156176406228 and parameters: {'sl': 12, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 75}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:09,719] Trial 90 finished with value: 0.8826769755464626 and parameters: {'sl': 10, 'tp': 23, 'LENGTH_RSI': 15, 'RSI_LOW': 23, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:10,371] Trial 91 finished with value: 1.5435357164085608 and parameters: {'sl': 8, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:11,007] Trial 92 finished with value: 1.6111371189420685 and parameters: {'sl': 8, 'tp': 18, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:11,639] Trial 93 finished with value: 0.9619407663219018 and parameters: {'sl': 8, 'tp': 18, 'LENGTH_RSI': 15, 'RSI_LOW': 24, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:12,295] Trial 94 finished with value: 0.9604513589064538 and parameters: {'sl': 12, 'tp': 18, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 74}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:12,952] Trial 95 finished with value: 1.551061717117368 and parameters: {'sl': 9, 'tp': 20, 'LENGTH_RSI': 16, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:13,589] Trial 96 finished with value: 1.1694113736698613 and parameters: {'sl': 4, 'tp': 20, 'LENGTH_RSI': 13, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:14,238] Trial 97 finished with value: 1.463381807925754 and parameters: {'sl': 9, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:14,901] Trial 98 finished with value: 1.736163492300392 and parameters: {'sl': 11, 'tp': 24, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:15,539] Trial 99 finished with value: 1.3068856428176858 and parameters: {'sl': 8, 'tp': 24, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 73}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:16,184] Trial 100 finished with value: -0.0010273488346205333 and parameters: {'sl': 11, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 46, 'RSI_HIGH': 75}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:16,825] Trial 101 finished with value: 0.3513648132777816 and parameters: {'sl': 6, 'tp': 10, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:17,468] Trial 102 finished with value: 1.4777853602395123 and parameters: {'sl': 11, 'tp': 20, 'LENGTH_RSI': 16, 'RSI_LOW': 22, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:18,089] Trial 103 finished with value: 1.4718469715990037 and parameters: {'sl': 9, 'tp': 19, 'LENGTH_RSI': 16, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:18,727] Trial 104 finished with value: -0.012825148605216018 and parameters: {'sl': 10, 'tp': 24, 'LENGTH_RSI': 15, 'RSI_LOW': 49, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:19,375] Trial 105 finished with value: 1.336584987501195 and parameters: {'sl': 8, 'tp': 14, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:20,031] Trial 106 finished with value: -2.762508584824824 and parameters: {'sl': 1, 'tp': 12, 'LENGTH_RSI': 16, 'RSI_LOW': 43, 'RSI_HIGH': 75}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:20,690] Trial 107 finished with value: 0.5350748936239283 and parameters: {'sl': 5, 'tp': 23, 'LENGTH_RSI': 8, 'RSI_LOW': 21, 'RSI_HIGH': 74}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:21,350] Trial 108 finished with value: -1.808004410989885 and parameters: {'sl': 10, 'tp': 5, 'LENGTH_RSI': 14, 'RSI_LOW': 24, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:22,019] Trial 109 finished with value: 1.3899332662570905 and parameters: {'sl': 11, 'tp': 17, 'LENGTH_RSI': 16, 'RSI_LOW': 20, 'RSI_HIGH': 73}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:22,660] Trial 110 finished with value: 1.5724909429446436 and parameters: {'sl': 9, 'tp': 21, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:23,310] Trial 111 finished with value: 1.4577917626816248 and parameters: {'sl': 9, 'tp': 25, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:23,974] Trial 112 finished with value: 1.526101531420337 and parameters: {'sl': 8, 'tp': 22, 'LENGTH_RSI': 15, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:24,610] Trial 113 finished with value: 1.4943440529908742 and parameters: {'sl': 8, 'tp': 22, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:25,250] Trial 114 finished with value: 1.4179874203413978 and parameters: {'sl': 6, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:25,886] Trial 115 finished with value: 1.293114529026795 and parameters: {'sl': 7, 'tp': 19, 'LENGTH_RSI': 15, 'RSI_LOW': 23, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:26,529] Trial 116 finished with value: 1.7591222718912547 and parameters: {'sl': 8, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:27,154] Trial 117 finished with value: 1.5626254848433652 and parameters: {'sl': 8, 'tp': 23, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:27,788] Trial 118 finished with value: 1.6773852430879896 and parameters: {'sl': 6, 'tp': 26, 'LENGTH_RSI': 13, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:28,431] Trial 119 finished with value: 0.9337826982257755 and parameters: {'sl': 3, 'tp': 26, 'LENGTH_RSI': 12, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:29,055] Trial 120 finished with value: 1.525356126645529 and parameters: {'sl': 5, 'tp': 24, 'LENGTH_RSI': 13, 'RSI_LOW': 20, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:29,689] Trial 121 finished with value: 1.6786671819474928 and parameters: {'sl': 8, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:30,309] Trial 122 finished with value: 1.84445171436703 and parameters: {'sl': 7, 'tp': 25, 'LENGTH_RSI': 13, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:30,931] Trial 123 finished with value: 0.5081629860045835 and parameters: {'sl': 6, 'tp': 23, 'LENGTH_RSI': 13, 'RSI_LOW': 21, 'RSI_HIGH': 53}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:31,549] Trial 124 finished with value: 1.3267689049158702 and parameters: {'sl': 7, 'tp': 20, 'LENGTH_RSI': 13, 'RSI_LOW': 22, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:32,174] Trial 125 finished with value: 1.431102449981264 and parameters: {'sl': 6, 'tp': 25, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:32,802] Trial 126 finished with value: 1.5364932943341425 and parameters: {'sl': 7, 'tp': 26, 'LENGTH_RSI': 12, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:33,440] Trial 127 finished with value: 1.5943123937320551 and parameters: {'sl': 8, 'tp': 18, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:34,067] Trial 128 finished with value: 0.3522498987655852 and parameters: {'sl': 5, 'tp': 18, 'LENGTH_RSI': 13, 'RSI_LOW': 23, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:34,690] Trial 129 finished with value: 0.8643004220211623 and parameters: {'sl': 4, 'tp': 23, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:35,314] Trial 130 finished with value: 1.658065195115475 and parameters: {'sl': 8, 'tp': 27, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:35,949] Trial 131 finished with value: 1.658065195115475 and parameters: {'sl': 8, 'tp': 27, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:36,580] Trial 132 finished with value: 1.4445567378010966 and parameters: {'sl': 8, 'tp': 28, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:37,205] Trial 133 finished with value: 1.494807626705327 and parameters: {'sl': 7, 'tp': 26, 'LENGTH_RSI': 13, 'RSI_LOW': 21, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:37,827] Trial 134 finished with value: 1.544953824514797 and parameters: {'sl': 6, 'tp': 27, 'LENGTH_RSI': 12, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:38,451] Trial 135 finished with value: 1.7283394399433598 and parameters: {'sl': 8, 'tp': 24, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:39,078] Trial 136 finished with value: 1.3099207999415665 and parameters: {'sl': 10, 'tp': 25, 'LENGTH_RSI': 13, 'RSI_LOW': 21, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:39,719] Trial 137 finished with value: 1.1479450799827444 and parameters: {'sl': 7, 'tp': 26, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:40,364] Trial 138 finished with value: -0.4510209982461744 and parameters: {'sl': 8, 'tp': 27, 'LENGTH_RSI': 14, 'RSI_LOW': 38, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:40,999] Trial 139 finished with value: 1.2969937345078966 and parameters: {'sl': 10, 'tp': 24, 'LENGTH_RSI': 13, 'RSI_LOW': 23, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:41,619] Trial 140 finished with value: 1.0777846897283423 and parameters: {'sl': 6, 'tp': 25, 'LENGTH_RSI': 14, 'RSI_LOW': 24, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:42,304] Trial 141 finished with value: 1.6828009297236752 and parameters: {'sl': 8, 'tp': 24, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:42,979] Trial 142 finished with value: 1.5595232696620631 and parameters: {'sl': 9, 'tp': 24, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:43,622] Trial 143 finished with value: 1.5078356935070107 and parameters: {'sl': 9, 'tp': 24, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:44,286] Trial 144 finished with value: 1.5875898902176535 and parameters: {'sl': 9, 'tp': 23, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:44,944] Trial 145 finished with value: -8.78456908143594 and parameters: {'sl': 10, 'tp': 1, 'LENGTH_RSI': 13, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:45,579] Trial 146 finished with value: 1.3830881644202904 and parameters: {'sl': 8, 'tp': 28, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:46,209] Trial 147 finished with value: 1.4474371441079912 and parameters: {'sl': 11, 'tp': 23, 'LENGTH_RSI': 13, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:46,849] Trial 148 finished with value: 1.5189520661029399 and parameters: {'sl': 7, 'tp': 25, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:47,487] Trial 149 finished with value: 1.7651864940126156 and parameters: {'sl': 12, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:48,116] Trial 150 finished with value: 1.6918834111844627 and parameters: {'sl': 13, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:48,753] Trial 151 finished with value: 1.3939555810770077 and parameters: {'sl': 14, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:49,391] Trial 152 finished with value: 1.4112079681447816 and parameters: {'sl': 13, 'tp': 26, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:50,024] Trial 153 finished with value: 1.5000971033559782 and parameters: {'sl': 12, 'tp': 27, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:50,655] Trial 154 finished with value: 1.1947282827825532 and parameters: {'sl': 13, 'tp': 22, 'LENGTH_RSI': 13, 'RSI_LOW': 22, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:51,305] Trial 155 finished with value: 1.5078356935070107 and parameters: {'sl': 9, 'tp': 24, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:51,944] Trial 156 finished with value: 1.6095497324545986 and parameters: {'sl': 12, 'tp': 23, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:52,573] Trial 157 finished with value: 1.0869743887702612 and parameters: {'sl': 14, 'tp': 15, 'LENGTH_RSI': 13, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:53,209] Trial 158 finished with value: 1.5150901167481918 and parameters: {'sl': 12, 'tp': 23, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:53,844] Trial 159 finished with value: 1.5846219752723487 and parameters: {'sl': 12, 'tp': 25, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:54,472] Trial 160 finished with value: -0.0827579678073877 and parameters: {'sl': 13, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 35, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:55,109] Trial 161 finished with value: 1.6970461303922293 and parameters: {'sl': 11, 'tp': 25, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:55,766] Trial 162 finished with value: 1.5475190429993115 and parameters: {'sl': 11, 'tp': 26, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:56,427] Trial 163 finished with value: 1.4863169212107936 and parameters: {'sl': 10, 'tp': 24, 'LENGTH_RSI': 13, 'RSI_LOW': 21, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:57,075] Trial 164 finished with value: 1.6226187948515363 and parameters: {'sl': 11, 'tp': 25, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:57,725] Trial 165 finished with value: 0.9720905810959878 and parameters: {'sl': 14, 'tp': 28, 'LENGTH_RSI': 10, 'RSI_LOW': 20, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:58,365] Trial 166 finished with value: 1.4317042527743071 and parameters: {'sl': 11, 'tp': 25, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 75}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:59,015] Trial 167 finished with value: 0.851812578346775 and parameters: {'sl': 13, 'tp': 27, 'LENGTH_RSI': 7, 'RSI_LOW': 20, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:56:59,649] Trial 168 finished with value: 1.3907518864946626 and parameters: {'sl': 12, 'tp': 24, 'LENGTH_RSI': 13, 'RSI_LOW': 21, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:00,274] Trial 169 finished with value: 1.410862193833701 and parameters: {'sl': 10, 'tp': 25, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:00,892] Trial 170 finished with value: 1.3143775646777167 and parameters: {'sl': 7, 'tp': 26, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 74}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:01,511] Trial 171 finished with value: 1.6453247640239979 and parameters: {'sl': 8, 'tp': 23, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:02,146] Trial 172 finished with value: 1.5899060362872428 and parameters: {'sl': 8, 'tp': 23, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:02,761] Trial 173 finished with value: 1.8176042407261122 and parameters: {'sl': 11, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:03,395] Trial 174 finished with value: 1.2592305120443712 and parameters: {'sl': 11, 'tp': 22, 'LENGTH_RSI': 13, 'RSI_LOW': 22, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:04,029] Trial 175 finished with value: 1.4131951030196774 and parameters: {'sl': 13, 'tp': 23, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 76}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:04,669] Trial 176 finished with value: 1.6108532574834011 and parameters: {'sl': 12, 'tp': 24, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:05,289] Trial 177 finished with value: 1.382982813763392 and parameters: {'sl': 11, 'tp': 27, 'LENGTH_RSI': 13, 'RSI_LOW': 21, 'RSI_HIGH': 75}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:05,914] Trial 178 finished with value: 1.5965328542832613 and parameters: {'sl': 10, 'tp': 24, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:06,536] Trial 179 finished with value: 1.116618783252042 and parameters: {'sl': 6, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 23, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:07,177] Trial 180 finished with value: 1.1004709004217126 and parameters: {'sl': 14, 'tp': 25, 'LENGTH_RSI': 12, 'RSI_LOW': 22, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:07,814] Trial 181 finished with value: 1.6847200892000658 and parameters: {'sl': 12, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 77}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:08,449] Trial 182 finished with value: 1.7651864940126156 and parameters: {'sl': 12, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:09,091] Trial 183 finished with value: 1.6918834111844627 and parameters: {'sl': 13, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:09,719] Trial 184 finished with value: 1.6918834111844627 and parameters: {'sl': 13, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 78}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:10,379] Trial 185 finished with value: 1.774387999307566 and parameters: {'sl': 13, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:11,044] Trial 186 finished with value: -0.014348708380220693 and parameters: {'sl': 15, 'tp': 21, 'LENGTH_RSI': 13, 'RSI_LOW': 32, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:11,661] Trial 187 finished with value: 1.774387999307566 and parameters: {'sl': 13, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:12,317] Trial 188 finished with value: 1.4808264801883944 and parameters: {'sl': 14, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:12,969] Trial 189 finished with value: 1.793901414423784 and parameters: {'sl': 13, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:13,602] Trial 190 finished with value: 1.3291872358387915 and parameters: {'sl': 13, 'tp': 22, 'LENGTH_RSI': 13, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:14,239] Trial 191 finished with value: 1.704820206207624 and parameters: {'sl': 13, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:14,885] Trial 192 finished with value: 1.3836067374550782 and parameters: {'sl': 15, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:15,535] Trial 193 finished with value: 1.4653629351442934 and parameters: {'sl': 14, 'tp': 22, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:16,169] Trial 194 finished with value: 1.704820206207624 and parameters: {'sl': 13, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:16,806] Trial 195 finished with value: 1.704820206207624 and parameters: {'sl': 13, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:17,454] Trial 196 finished with value: 1.2867480355188792 and parameters: {'sl': 13, 'tp': 21, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:18,099] Trial 197 finished with value: 1.2080279181234608 and parameters: {'sl': 13, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 22, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:18,733] Trial 198 finished with value: 1.721274498779935 and parameters: {'sl': 12, 'tp': 20, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:19,375] Trial 199 finished with value: 1.7144462097529143 and parameters: {'sl': 12, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:20,007] Trial 200 finished with value: 0.8682012214918639 and parameters: {'sl': 14, 'tp': 19, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:20,638] Trial 201 finished with value: 1.721274498779935 and parameters: {'sl': 12, 'tp': 20, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:21,271] Trial 202 finished with value: 1.7948254943311124 and parameters: {'sl': 12, 'tp': 20, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:21,901] Trial 203 finished with value: 1.7144462097529143 and parameters: {'sl': 12, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:22,656] Trial 204 finished with value: 1.3937723931461201 and parameters: {'sl': 13, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:23,301] Trial 205 finished with value: 1.3486005767039602 and parameters: {'sl': 12, 'tp': 19, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:23,947] Trial 206 finished with value: -0.0032662610364211225 and parameters: {'sl': 12, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 43, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:24,569] Trial 207 finished with value: 1.7144462097529143 and parameters: {'sl': 12, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:25,199] Trial 208 finished with value: 1.3486005767039602 and parameters: {'sl': 12, 'tp': 19, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:25,829] Trial 209 finished with value: 1.6362830007647067 and parameters: {'sl': 12, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:26,455] Trial 210 finished with value: 1.041730268707899 and parameters: {'sl': 14, 'tp': 21, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:27,075] Trial 211 finished with value: 1.82118219706857 and parameters: {'sl': 12, 'tp': 21, 'LENGTH_RSI': 14, 'RSI_LOW': 20, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:27,693] Trial 212 finished with value: 1.8126754523690112 and parameters: {'sl': 11, 'tp': 20, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:28,330] Trial 213 finished with value: 1.7948254943311124 and parameters: {'sl': 12, 'tp': 20, 'LENGTH_RSI': 14, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:28,959] Trial 214 finished with value: 1.7372156547368638 and parameters: {'sl': 11, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:29,596] Trial 215 finished with value: 0.756145473879323 and parameters: {'sl': 11, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 58}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:30,234] Trial 216 finished with value: 1.5115946155780993 and parameters: {'sl': 12, 'tp': 19, 'LENGTH_RSI': 15, 'RSI_LOW': 22, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:30,859] Trial 217 finished with value: 1.1922459476496552 and parameters: {'sl': 11, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 23, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:31,533] Trial 218 finished with value: 1.622355971792777 and parameters: {'sl': 12, 'tp': 19, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 79}. Best is trial 70 with value: 2.4002765692720347.
# [I 2025-06-28 20:57:32,214] Trial 219 finished with value: 1.5388444547663038 and parameters: {'sl': 11, 'tp': 20, 'LENGTH_RSI': 15, 'RSI_LOW': 21, 'RSI_HIGH': 80}. Best is trial 70 with value: 2.4002765692720347.

# %%
study.best_params
# Out:
# {'sl': 13, 'tp': 12, 'LENGTH_RSI': 16, 'RSI_LOW': 20, 'RSI_HIGH': 79}
